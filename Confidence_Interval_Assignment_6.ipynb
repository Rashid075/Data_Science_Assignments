# %% [markdown]
# # Estimation and Confidence Intervals

# %% [markdown]
# ### 1. Building 99% Confidence Interval Using Sample Standard Deviation

# %%
import numpy as np
import pandas as pd
from scipy import stats

# %%
data=np.array([1.13, 1.55, 1.43, 0.92, 1.25, 1.36, 1.32, 0.85, 1.07, 1.48, 1.20, 1.33, 1.18, 1.22, 1.29])
data
# Out:
# array([1.13, 1.55, 1.43, 0.92, 1.25, 1.36, 1.32, 0.85, 1.07, 1.48, 1.2 ,
#        1.33, 1.18, 1.22, 1.29])

# %%
#sample size
n = len(data)

# %%
#sample mean
mean = np.mean(data)
mean
# Out:
# np.float64(1.2386666666666666)

# %%
#sample standard deviation
std_dev = np.std(data, ddof=1)
std_dev
# Out:
# np.float64(0.19316412956959936)

# %%
#Confidence Level
confidence_level = 0.99
alpha = 1 - confidence_level
alpha
# Out:
# 0.010000000000000009

# %%
#degrees of freedom
df = n-1

# %%
# t critical value
t_critical = stats.t.ppf(1-alpha/2, df)
t_critical
# Out:
# np.float64(2.976842734370834)

# %%
# Margin of Error
margin_error = t_critical * (std_dev/np.sqrt(n))
margin_error
# Out:
# np.float64(0.14846932822817596)

# %%
#Confidence Intervals
lower_bound = mean - margin_error
upper_bound = mean + margin_error
lower_bound, upper_bound
# Out:
# (np.float64(1.0901973384384906), np.float64(1.3871359948948425))

# %%
results_df = pd.DataFrame({
    "Sample Size (n)": [n],
    "Sample Mean": [mean],
    "Sample Std Deviation": [std_dev],
    "Degrees of Freedom": [df],
    "Confidence Level": [confidence_level],
    "t Critical Value": [t_critical],
    "Margin of Error": [margin_error],
    "Lower CI": [lower_ci],
    "Upper CI": [upper_ci]
})
results_df
# Out:
#    Sample Size (n)  Sample Mean  Sample Std Deviation  Degrees of Freedom  \
# 0               15     1.238667              0.193164                  14
#
#    Confidence Level  t Critical Value  Margin of Error  Lower CI  Upper CI
# 0              0.99          2.976843         0.133015  1.105651  1.371682

# %% [markdown]
# ### 2. Build 99% Confidence Interval Using Known Population Standard Deviation

# %%
# population standard deviation
sigma = 0.2

# %%
#Calculations
n = len(data)
mean = np.mean(data)
confidence_level = 0.99
alpha = 1 - confidence_level

# %%
# z critical value
z_critical = stats.norm.ppf(1-alpha/2)
z_critical
# Out:
# np.float64(2.5758293035489004)

# %%
# Margin of Error
margin_error = z_critical * (sigma/np.sqrt(n))
margin_error
# Out:
# np.float64(0.13301525327090588)

# %%
# Confidence interval
lower_ci = mean - margin_error
upper_ci = mean + margin_error
lower_ci, upper_ci
# Out:
# (np.float64(1.1056514133957607), np.float64(1.3716819199375725))

# %%
#Create DataFrame with seperate columns
results_df = pd.DataFrame({
    "Sample Size (n)": [n],
    "Sample Mean": [mean],
    "Population Std Deviation (σ)": [sigma],
    "Confidence Level": [confidence_level],
    "z Critical Value": [z_critical],
    "Margin of Error": [margin_error],
    "Lower CI": [lower_ci],
    "Upper CI": [upper_ci]
})
results_df
# Out:
#    Sample Size (n)  Sample Mean  Population Std Deviation (σ)  \
# 0               15     1.238667                           0.2
#
#    Confidence Level  z Critical Value  Margin of Error  Lower CI  Upper CI
# 0              0.99          2.575829         0.133015  1.105651  1.371682
